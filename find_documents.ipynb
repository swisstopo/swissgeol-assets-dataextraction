# %%
import os
import pandas as pd
from PyPDF2 import PdfMerger, PdfWriter, PdfReader

base_dir = os.getcwd() 

input_folder = os.path.join(base_dir,"data/legaldocs_redo/buchi_muller_ldocs")
output_folder = os.path.join(base_dir,"data/legaldocs_redo/ldocs_new")
extend_with = os.path.join(base_dir,"data/legaldocs_redo/extend_with")

# %%
## find all files with certain keyword in all subfolders of base directory

def search_files_and_folders(base_dir, keyword):
    matches = {'files': [], 'folders': []}
    
    for root, dirs, files in os.walk(base_dir):
        for d in dirs:
            if keyword.lower() in d.lower():
                matches['folders'].append(os.path.join(root, d))

        for f in files:
            if keyword.lower() in f.lower():
                matches['files'].append(os.path.join(root, f))

    return matches

base_directory = "/home/lillemor/"

# keyword = "Baersol"
# results = search_files_and_folders(base_directory, keyword)
        
# for folder in results['folders']:
#     print(folder)

# for file in results['files']:
#     print(file)

# %%
## extend legaldocs of büchi mülle with legal docs of csd

csv_file = os.path.join(base_dir, "data/legaldocs_redo/Büchi_müller_ag.csv")
df = pd.read_csv(csv_file)

sgs_ids = df['sgs_id'].dropna().astype(int).astype(str).tolist()

print("$sgsIds = @(")
for i, sgs_id in enumerate(sgs_ids):
    end = "," if i < len(sgs_ids) - 1 else ""  # Add comma except for the last item
    print(f'    "{sgs_id}"{end}')
print(")")
# Out:
# $sgsIds = @(
#     "11829",
#     "17329",
#     "17330",
#     "17331",
#     "17332",
#     "17333",
#     "17334",
#     "17335",
#     "17337",
#     "17338",
#     "17339",
#     "18830",
#     "18833",
#     "18834",
#     "18857",
#     "18859",
#     "19466",
#     "20777",
#     "21081",
#     "21644",
#     "21645",
#     "21646",
#     "21648",
#     "21655",
#     "21656",
#     "21679",
#     "27874",
#     "27875",
#     "27876",
#     "27877",
#     "27878",
#     "27879",
#     "27880",
#     "27881",
#     "27882",
#     "27883",
#     "27884",
#     "27885",
#     "27886",
#     "27887",
#     "27888",
#     "27889",
#     "27890",
#     "27891",
#     "27892",
#     "27893",
#     "27894",
#     "27895",
#     "27896",
#     "27897",
#     "27911",
#     "27984",
#     "27985",
#     "27986",
#     "27987",
#     "27988",
#     "27989",
#     "27990",
#     "27991",
#     "27992",
#     "27993",
#     "27994",
#     "27995",
#     "27996",
#     "28071",
#     "28072",
#     "28073",
#     "28074",
#     "28075",
#     "28076",
#     "28077",
#     "28078",
#     "28079",
#     "28088",
#     "28121",
#     "28122",
#     "28123",
#     "28124",
#     "28125",
#     "28126",
#     "28127",
#     "28128",
#     "28240",
#     "28241",
#     "28242",
#     "28243",
#     "28244",
#     "28245",
#     "28351",
#     "28358",
#     "28632",
#     "28633",
#     "28640",
#     "28641",
#     "28644",
#     "28645",
#     "28646",
#     "28647",
#     "28648",
#     "28650",
#     "28651",
#     "28652",
#     "28653",
#     "28654",
#     "28658",
#     "28659",
#     "28660",
#     "28662",
#     "28663",
#     "28664",
#     "28666",
#     "28849",
#     "28852",
#     "28853",
#     "28854",
#     "28855",
#     "28860",
#     "30039",
#     "31268",
#     "31279",
#     "33327",
#     "44102",
#     "12360",
#     "12366",
#     "12376",
#     "15392",
#     "16130",
#     "16990",
#     "16994",
#     "16995",
#     "17336",
#     "17550",
#     "17571",
#     "17572",
#     "17582",
#     "17585",
#     "17827",
#     "18067",
#     "18076",
#     "19191",
#     "27095",
#     "27262",
#     "29186",
#     "29679",
#     "29681",
#     "30961",
#     "30962",
#     "31271",
#     "31355",
#     "31603",
#     "32823",
#     "32824",
#     "32825",
#     "32826",
#     "32827",
#     "32828",
#     "32829",
#     "32830",
#     "32831",
#     "32832",
#     "32833",
#     "32834",
#     "32835",
#     "32836",
#     "32837",
#     "32838",
#     "32839",
#     "32840",
#     "32841",
#     "32842",
#     "32843",
#     "32844",
#     "32845",
#     "32846",
#     "32847",
#     "32848",
#     "39209",
#     "44136",
#     "44194",
#     "402",
#     "32849",
#     "32850"
# )

# %%
import os

pdf_files = [file.lower() for file in os.listdir(input_folder) if file.lower().endswith(".pdf")]
print(len(pdf_files))

missing_docs = []

# Check if each sgs_id is found in the filenames
for sgs_id in sgs_ids:
    if not any(f"{sgs_id}" in file for file in pdf_files):  # Fixed issue here
        missing_docs.append(sgs_id)  # Fixed issue here

print(f"Total missing legal docs: {len(missing_docs)}")
print("Missing asset IDs:", missing_docs)
# Out:
# 179
# Total missing legal docs: 3
# Missing asset IDs: ['44102', '44136', '44194']

# %%
pdfs_to_merge = [
    ("CSD-Liebefeld-20060620.pdf", [0]),        # First page
    ("CSD-VD-19860624.pdf", [0, 2]),            # First and third page
    ("CSD-VD-20070702.pdf", [0, 2]),            # First and third page
    ("CSD-Liebefeld-19810911.pdf", [0]),        # First page
    ("CSD-19730309-2.pdf", [0]),                # First page
    ("CSD-19730309-1.pdf", [0,1]),                # First page
    ("CSD-19720525.pdf", [0])                   # First page
]

# %%
##create merged CSD legal doc
pdf_writer = PdfWriter()
merged_output_pdf = os.path.join(os.getcwd(), "data/legaldocs_redo/extend_with/CSD_LegalDocs_merged.pdf")

for pdf_file, pages in pdfs_to_merge:
    pdf_path = os.path.join(extend_with, pdf_file)
    
    if os.path.exists(pdf_path):  # Check if file exists
        pdf_reader = PdfReader(pdf_path)
        
        for page_num in pages:
            if page_num < len(pdf_reader.pages):  # Ensure page exists
                pdf_writer.add_page(pdf_reader.pages[page_num])
            else:
                print(f"Warning: {pdf_file} does not have page {page_num + 1}")
    else:
        print(f"Warning: File not found: {pdf_file}")

# Save the merged PDF
with open(merged_output_pdf, "wb") as output_file:
    pdf_writer.write(output_file)

print(f"Merged PDF created at: {merged_output_pdf}")
# Out:
# Merged PDF created at: /home/lillemor/Documents/lgd-utils/asset-data-extraction/data/legaldocs_redo/extend_with/CSD_LegalDocs_merged.pdf

# %%
merged_csd_pdf = os.path.join(base_dir, "data/legaldocs_redo/extend_with/CSD_LegalDocs_merged.pdf")
csd_overtake = os.path.join(base_dir, "data/legaldocs_redo/extend_with/CSD_uebernahme.pdf")

#check that output directory exists
os.makedirs(output_folder, exist_ok=True)
# Check if merged CSD legal doc and csd overtake doc exist
if not os.path.exists(merged_csd_pdf):
    raise FileNotFoundError(f"Merged CSD document not found: {merged_csd_pdf}")
if not os.path.exists(csd_overtake):
    raise FileNotFoundError(f"CSD takeover document not found: {csd_overtake}")

csd_overtake_reader = PdfReader(csd_overtake)
csd_reader = PdfReader(merged_csd_pdf)

for file in os.listdir(input_folder):
    if file.lower().endswith(".pdf"):
        input_pdf_path = os.path.join(input_folder, file)
        output_pdf_path = os.path.join(output_folder, file)

        # Read input pdf
        input_reader = PdfReader(input_pdf_path)
        pdf_writer = PdfWriter()

        # Add all pages from input pdf
        for page in input_reader.pages:
            pdf_writer.add_page(page)
            
        # Add the CSD takeover document
        for page in csd_overtake_reader.pages:
            pdf_writer.add_page(page)
            
        # Append all pages from the merged CSD legaldoc
        for page in csd_reader.pages:
            pdf_writer.add_page(page)

        # Save the extended PDF
        with open(output_pdf_path, "wb") as output_file:
            pdf_writer.write(output_file)

        print(f"Extended and saved: {file}")

print("\nAll PDFs have been extended with the CSD legal docs.")
# Out:
# Extended and saved: 32839_LDoc.pdf
# Extended and saved: 28128_LDoc.pdf
# Extended and saved: 32824_LDoc.pdf
# Extended and saved: 27988_LDoc.pdf
# Extended and saved: 32841_LDoc.pdf
# Extended and saved: 31355_LDoc.pdf
# Extended and saved: 28122_LDoc.pdf
# Extended and saved: 27996_LDoc.pdf
# Extended and saved: 28125_LDoc.pdf
# Extended and saved: 28124_LDoc.pdf
# Extended and saved: 28664_LDoc.pdf
# Extended and saved: 28860_LDoc.pdf
# Extended and saved: 27897_LDoc.pdf
# Extended and saved: 27895_LDoc.pdf
# Extended and saved: 28071_LDoc.pdf
# Extended and saved: 28648_LDoc.pdf
# Extended and saved: 28640_LDoc.pdf
# Extended and saved: 28243_LDoc.pdf
# Extended and saved: 17582_LDoc.pdf
# Extended and saved: 28644_LDoc.pdf
# Extended and saved: 28121_LDoc.pdf
# Extended and saved: 28127_LDoc.pdf
# Extended and saved: 18834_LDoc.pdf
# Extended and saved: 28650_LDoc.pdf
# Extended and saved: 15392_LDoc.pdf
# Extended and saved: 28645_LDoc.pdf
# Extended and saved: 27884_LDoc.pdf
# Extended and saved: 17572_LDoc.pdf
# Extended and saved: 28632_LDoc.pdf
# Extended and saved: 12376_LDoc.pdf
# Extended and saved: 28663_LDoc.pdf
# Extended and saved: 27877_LDoc.pdf
# Extended and saved: 28658_LDoc.pdf
# Extended and saved: 27984_LDoc.pdf
# Extended and saved: 32825_LDoc.pdf
# Extended and saved: 32849_LDoc.pdf
# Extended and saved: 32838_LDoc.pdf
# Extended and saved: 17827_LDoc.pdf
# Extended and saved: 18830_LDoc.pdf
# Extended and saved: 32833_LDoc.pdf
# Extended and saved: 32834_LDoc.pdf
# Extended and saved: 21645_LDoc.pdf
# Extended and saved: 32846_LDoc.pdf
# Extended and saved: 32829_LDoc.pdf
# Extended and saved: 32843_LDoc.pdf
# Extended and saved: 17331_LDoc.pdf
# Extended and saved: 28852_LDoc.pdf
# Extended and saved: 18076_LDoc.pdf
# Extended and saved: 27989_LDoc.pdf
# Extended and saved: 19191_LDoc.pdf
# Extended and saved: 17335_LDoc.pdf
# Extended and saved: 28653_LDoc.pdf
# Extended and saved: 27880_LDoc.pdf
# Extended and saved: 17571_LDoc.pdf
# Extended and saved: 18857_LDoc.pdf
# Extended and saved: 27883_LDoc.pdf
# Extended and saved: 27875_LDoc.pdf
# Extended and saved: 28126_LDoc.pdf
# Extended and saved: 17336_LDoc.pdf
# Extended and saved: 21644_LDoc.pdf
# Extended and saved: 18833_LDoc.pdf
# Extended and saved: 32845_LDoc.pdf
# Extended and saved: 27990_LDoc.pdf
# Extended and saved: 32840_LDoc.pdf
# Extended and saved: 27893_LDoc.pdf
# Extended and saved: 28660_LDoc.pdf
# Extended and saved: 17339_LDoc.pdf
# Extended and saved: 28088_LDoc.pdf
# Extended and saved: 27911_LDoc.pdf
# Extended and saved: 27995_LDoc.pdf
# Extended and saved: 17332_LDoc.pdf
# Extended and saved: 17337_LDoc.pdf
# Extended and saved: 27894_LDoc.pdf
# Extended and saved: 27095_LDoc.pdf
# Extended and saved: 28654_LDoc.pdf
# Extended and saved: 16990_LDoc.pdf
# Extended and saved: 28078_LDoc.pdf
# Extended and saved: 28245_LDoc.pdf
# Extended and saved: 28641_LDoc.pdf
# Extended and saved: 17585_LDoc.pdf
# Extended and saved: 27876_LDoc.pdf
# Extended and saved: 28076_LDoc.pdf
# Extended and saved: 28075_LDoc.pdf
# Extended and saved: 27985_LDoc.pdf
# Extended and saved: 32837_LDoc.pdf
# Extended and saved: 28662_LDoc.pdf
# Extended and saved: 12366_LDoc.pdf
# Extended and saved: 28351_LDoc.pdf
# Extended and saved: 32842_LDoc.pdf
# Extended and saved: 16130_LDoc.pdf
# Extended and saved: 28647_LDoc.pdf
# Extended and saved: 27887_LDoc.pdf
# Extended and saved: 32835_LDoc.pdf
# Extended and saved: 27994_LDoc.pdf
# Extended and saved: 27882_LDoc.pdf
# Extended and saved: 30961_LDoc.pdf
# Extended and saved: 21679_LDoc.pdf
# Extended and saved: 28074_LDoc.pdf
# Extended and saved: 21081_LDoc.pdf
# Extended and saved: 17329_LDoc.pdf
# Extended and saved: 17338_LDoc.pdf
# Extended and saved: 27986_LDoc.pdf
# Extended and saved: 32823_LDoc.pdf
# Extended and saved: 28123_LDoc.pdf
# Extended and saved: 28666_LDoc.pdf
# Extended and saved: 21655_LDoc.pdf
# Extended and saved: 28849_LDoc.pdf
# Extended and saved: 27886_LDoc.pdf
# Extended and saved: 28242_LDoc.pdf
# Extended and saved: 30962_LDoc.pdf
# Extended and saved: 27888_LDoc.pdf
# Extended and saved: 27878_LDoc.pdf
# Extended and saved: 28853_LDoc.pdf
# Extended and saved: 32826_LDoc.pdf
# Extended and saved: 27874_LDoc.pdf
# Extended and saved: 32827_LDoc.pdf
# Extended and saved: 27262_LDoc.pdf
# Extended and saved: 28659_LDoc.pdf
# Extended and saved: 32831_LDoc.pdf
# Extended and saved: 21646_LDoc.pdf
# Extended and saved: 32830_LDoc.pdf
# Extended and saved: 32847_LDoc.pdf
# Extended and saved: 17334_LDoc.pdf
# Extended and saved: 28651_LDoc.pdf
# Extended and saved: 32828_LDoc.pdf
# Extended and saved: 20777_LDoc.pdf
# Extended and saved: 27993_LDoc.pdf
# Extended and saved: 27992_LDoc.pdf
# Extended and saved: 27896_LDoc.pdf
# Extended and saved: 32848_LDoc.pdf
# Extended and saved: 31603_LDoc.pdf
# Extended and saved: 33327_LDoc.pdf
# Extended and saved: 17330_LDoc.pdf
# Extended and saved: 29186_LDoc.pdf
# Extended and saved: 27991_LDoc.pdf
# Extended and saved: 28241_LDoc.pdf
# Extended and saved: 28072_LDoc.pdf
# Extended and saved: 11829_LDoc.pdf
# Extended and saved: 27889_LDoc.pdf
# Extended and saved: 28855_LDoc.pdf
# Extended and saved: 27881_LDoc.pdf
# Extended and saved: 28854_LDoc.pdf
# Extended and saved: 31279_LDoc.pdf
# Extended and saved: 18067_LDoc.pdf
# Extended and saved: 30039_LDoc.pdf
# Extended and saved: 28358_LDoc.pdf
# Extended and saved: 16995_LDoc.pdf
# Extended and saved: 27891_LDoc.pdf
# Extended and saved: 28073_LDoc.pdf
# Extended and saved: 18859_LDoc.pdf
# Extended and saved: 28079_LDoc.pdf
# Extended and saved: 21656_LDoc.pdf
# Extended and saved: 12360_LDoc.pdf
# Extended and saved: 29679_LDoc.pdf
# Extended and saved: 402_LDoc.pdf
# Extended and saved: 27879_LDoc.pdf
# Extended and saved: 29681_LDoc.pdf
# Extended and saved: 27885_LDoc.pdf
# Extended and saved: 31268_LDoc.pdf
# Extended and saved: 28240_LDoc.pdf
# Extended and saved: 16994_LDoc.pdf
# Extended and saved: 21648_LDoc.pdf
# Extended and saved: 31271_LDoc.pdf
# Extended and saved: 28077_LDoc.pdf
# Extended and saved: 27890_LDoc.pdf
# Extended and saved: 28646_LDoc.pdf
# Extended and saved: 17550_LDoc.pdf
# Extended and saved: 19466_LDoc.pdf
# Extended and saved: 28244_LDoc.pdf
# Extended and saved: 39209_LDoc.pdf
# Extended and saved: 32844_LDoc.pdf
# Extended and saved: 32836_LDoc.pdf
# Extended and saved: 28633_LDoc.pdf
# Extended and saved: 28652_LDoc.pdf
# Extended and saved: 17333_LDoc.pdf
# Extended and saved: 32832_LDoc.pdf
# Extended and saved: 27987_LDoc.pdf
# Extended and saved: 32850_LDoc.pdf
# Extended and saved: 27892_LDoc.pdf
#
# All PDFs have been extended with the CSD legal docs.
