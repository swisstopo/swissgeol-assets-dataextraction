# %%
import fitz
import os
base_dir = os.getcwd()

# %%
pdf_path = "data/NAB/Berichte_NAB 10-025_Kurzarbeitsprogram Geothermiebohrung Schlattingen.PDF"
pdf_path = "data/NAB/Berichte_NAB 20-001_QBO Trüllikon-Rudolfingen Appendices/"

def text_from_document(file_path) -> dict:
    """ Retrieve text per page from a single pdf file
    Returns dictionary with pagenumber as key and all text on that page as item"""
    doc = fitz.open(file_path)

    page_text= {}
    for page_index, page in enumerate(doc):
        page_number = page_index + 1
        text = page.get_text()
        
        page_text[page_number]= text
    
    return(page_text)

def process_documents(input_path):
    """ Retrieves text from input file or folder and returns dictionary"""
    
    results = {}
    
    if os.path.isfile(input_path):
        results[os.path.basename(input_path)] = text_from_document(input_path)

    elif os.path.isdir(input_path):
        for filename in os.listdir(input_path):
            if filename.lower().endswith('.pdf'):
                file_path = os.path.join(input_path, filename)
                results[filename] = text_from_document(file_path)
    else:
        print(f"Input path is invalid: {input_path}")
    
    return results

# %%
document_text =process_documents(pdf_path)

# %%
for page_num, text in document_text.items():
    print(f"Document: {page_num}:\n {text}")
# Out:
# Document: App-B2_Geological Profile.pdf:
#  {1: 'Lower \nFreshwater\nMolasse\n(USM)\n0.9\n1.6\n2.7\n6.9\n411.9\n411.2\n410.1\n405.9\n404.6\n404.1\n399.8\n394.6\n389.4\n382.0\n378.8\n374.6\n373.8\n324.8\n325.8\n327.8\n332.8\n337.0\n339.9\n339.4\n341.7\n342.2\n342.8\n346.8\n351.8\n358.0\n358.8\n361.2\n363.8\n366.9\n367.2\n370.6\n371.3\n332.3\n323.4\n322.8\n321.3\n319.8\n318.3\n318.0\n316.3\n316.2\n314.4\n313.8\nCover sediments, \nw. soil formation\nFluvial/deltaic \ngravels\nLacustrine\nsands and fines \n(coarsening \nupward trend)\nGlacilacustrine to \nlacustrine fines\nGlacilacustrine \nfines\n(with dropstones)\nGlacilacustrine \nsediments\n(base possibly \nglacideltaic,\nfining upward \ntrend)\nGlacigenic \ndiamicts / tills\n8.2\n8.7\n13.0\n18.2\n19.6\n19.8\n20.3\n20.4\n22.5\n22.3\n18.4\n23.4\n30.8\n30.7\n29.5\n29.8\n27.4\n27.6\n26.5\n26.8\n25.0\n25.3\n34.0\n38.2\n39.0\n42.2\n41.5\n87.0\n80.5\n75.8\n73.4\n80.0\n72.9\n71.1\n70.6\n70.0\n66.0\n61.0\n51.6\n49.0\n45.9\n45.6\n54.0\n54.8\n85.0\n88.0\n89.4\n90.0\n99.0\n98.4\n96.5\n94.8\n94.5\n93.0\n91.5\n96.6\nComments\nPreliminary\nCoring\ntool\ninterpretation\nElev.\na.s.l.\nComposite \ndepth [m] \nLithological description\nSed.\nstruct.\nNAGRA, Hardstrasse 73, 5430 Wettingen\nBlétry AG, Küttigen\nDidier Blétry\n2’691’937.45 / 1’277’352.65\n412.83 m a.s.l.\n15.02. - 05.04.2019\nBuilding contractor:\nDrilling company:\nDriller:\nGeological logging:\nDrilling period:\nCoordinates:\nMarius Huber, Dominik Amschwand, Marius Buechi\nGround level:\nQuartärbohrungen Tranche 2\nQBO Trüllikon-Rudolfingen\nScale 1:100\nRudolfingen Trough\nQuaternary Geology and Paleoclimatology \nInstitute of Geological Sciences\nUniversity of Bern\nBaltzerstrasse 1+3\n3012 Bern\nDüsterloh hammer (133 mm)\nDüsterloh hammer (133 mm)\nDüsterloh hammer (133 mm)\nDüsterloh hammer (133 mm)\nDüsterloh hammer (133 mm)\nDüsterloh hammer (133 mm)\nDüsterloh\nhammer\n(133 mm)\nCSK\n(146 mm)\nCSK\n(146 mm)\nCSK\n(146 mm)\n Wireline coring with 550L polymer fluid (CSK 146 mm)\nSilt, sandy and Silt, sandy, gravelly, diamictic; matrix-supported; poorly sorted; massive; \nwith organic matter (roots, etc.); colours: moderate brown (5YR 4/4), dark yellowish \norange (10YR 6/6) moderate yellowish brown (10YR 5/4); dense/stiff; no reaction with HCl\nSand, gravelly interbedded with Gravel, sandy; \nSand beds (thickn. 5-30 cm): well sorted; internal bedding and grading common; with \ngravelly beds (dispersed gravel clasts) and silty laminae; light olive brown or grey (5Y 5/6; \n5Y 5/2), dusky yellow (5Y 6/4), dusky yellowish brown (10YR 2/2), dark grey (N3); \nmedium dense\nGravel beds (thickn. 5-40 cm): massive or crude bedding and grading; slightly thickening \nand coarsening upward trend; olive grey (5Y 3/2 and 5Y 5/2), moderate olive and pale \nyellowish brown (5Y 4/4, 10YR 6/2); loose-dense\nGravel, sandy to very sandy, clast-supported; moderately sorted; massive to crudely \nbedded with thin sand lenses (cm-scale thickness); greyish orange (10YR 7/4), pale \nyellowish brown (10YR 6/2), dark yellowish orange (10YR 6/6); dense\nGravel, sandy, silty; clast-supported; poorly sorted; massive - crudely bedded, cm-scale \nsand pockets/lenses; dark yellowish orange (10YR 6/6), moderate yellowish brown (10YR \n5/4); dense - very dense; locally calcite cemented (mainly on bottom sides of clasts)\nMedium - coarse Sand, gravelly; moderately sorted; bedding and grading common, \ngravel clasts dispersed; mainly light olive grey (5Y 5/2), light brown (5YR 6/4); medium \ndense - dense; \n7.3-7.4 m: cemented sand aggregates (cm-scale, probably in-situ cementation)\nca. 6-13 m: cores very wet/soaked, sediments \npartly fluidized\n40-50 m increased coring disturbance due to \ncore-catcher flap mechanism, after 50 m \nswitched back to regular core catcher springs\nca. 66-88 m: hard to penetrate and variably \ncohesive/coarse-grained lithologies required \nrepeated switching between coring tools to \nmaintain high core recovery and quality \nca. 4 m: groundwater entering borehole\nFine  ...
# Document: App-A1_Legend Symbols.pdf:
#  {1: 'Sedimentary structures & other symbols\nSampling & in-situ testing\nNormal graded bedding\nInverse graded bedding\nGradational contact\nErosional surface\nIrregular sharp contact\nPlanar sharp contact\nRecovery / core quality \nDropstone\nContorted bedding, slumping\nBioturbation\nPlant fragments\nStriated clasts\nPossibly disturbed \n(part of composite section)\nStrongly disturbed (infall/recore) and gaps\n(not part of composite section)\nPlant root tubes, rootlets\nBulk sediment sample\nLuminescence sample\nPore water sample\nSmear slide\nVane shear measurement\nVS\nPW\nBS\nLUM\nSS\nCementation (locally)\nCarbonate concretion/nodule\nMica-rich\nNAB 20-01\nAPPENDIX A1\nLegend for symbols used in profiles and core log sheets\nDAT.: July 2020\nQTRU Data Report\n'}
# Document: App-A2_Legend LithoPattern.pdf:
#  {1: 'saGr \nGravel, sandy\nGrSa\n \nGravel/Sand\nsasiGr - saclGr\nGravel, well sorted,\nwith silt, sand and clay\nsiGr - sasiGr\n \nGravel, poorly sorted,\nwith sand and silt\nsasiGr \nGravel, silty and\nsandy, \nwith cobbles\nsiGr - clGr\n Gravel, silty to clayey\nGr \nGravel, well sorted\ncoGr \nGravel, \nwith cobbles\nMain Component Gravel\nSa \nSand, well sorted\nFSa\n fine Sand\n(si)Sa\nSand, slightly silty\n(cl)Sa\nSand, slightly clayey\nsiSa\nSand, strongly silty\nclSa\nSand, strongly clayey \nsiclSa - clsiSa\nSand, silty / clayey\ngrSa  \nSand, with gravel\nMSa\n middle Sand\nsigrSa - grsiSa\nSand, silty, with gravel\nSand gravelly, with silt\nclgrSa - grclSa\nSand, gravelly with clay\nSand, clayey, with gravel \nsiclgrSa\n \nSand, gravelly, with\nsilt and clay\nCSa\n coarse Sand\nMain Component Sand \nSi\nSilt\nsiCl\nClay, siltiy\nCl\nClay\nsaSi\nSilt, sandy\nsisaCl - sasiCl\nClay, silty, sandy\nClay, sandy, silty\nsaCl\nClay, sandy\nsagrSi - grsaSi\nSilt, sandy, \ngravelly\ngrsiCl\nClay, gravelly, siltiy\ngrCl - grsaCl   \nClay, gravelly to\nClay, sandy, \ngravelly\nclSi\nSilt, clayey\nsaclSi - clsaSi\nSilt, sandy, clayey\nSilt, clayey, sandy\ngrSi, grclSi\nSilt, gravelly to\nSilt, gravelly and \nclayey\nMain Components Silt and Clay\nsiOr\nSilt, organic\nsasiOr\norganic Silt,\nsandy / with sand\nsagrsiOr\norganic Silt with\nsand and gravel\nsiclOr\nSilt and Clay,\norganic\nsaclsiOr\norganic Silt, clayey,\nwith sand\nsagrsiclOr\norganic Silt and Clay\nwith sand and gravel\nclOr\nClay, organic\nsaclOr   \norganic Clay\nwith sand\nsagrclOr\norganic Clay with\nsand and gravel\nPt\nPeat\nsaPt   \nPeat, sandy\nsagrPt  \nPeat with\nsand and gravel\nOrganic Soils\nFor lithology patterns of bedrock and references \nof lithology patterns refer to Naef et al. (2019) \nAPPENDIX A2\nNAB 20-01\nLithology patterns used in profiles and core log sheets\nQTRU Data Report\nDAT.: July 2020\n'}
# Document: App-D_Recovery.pdf:
ilkernrohr CSK, \nPolymer Spülung \n \nVerrohrung \nVon \n0.0 m \nBis \n33.0 m \nDurchmesser \n324 mm \nSpezifikation \nBohrrohre \n0.0 m \n50.0 m \n273 mm \nBohrrohre \n0.0 m \n72.0 m \n219 mm \nBohrrohre \n0.0 m \n88.0 m \n178 mm \nBohrrohre \n \nSpülung \nVon \nBis \nDetails \nSpezifikation \n67.2 m \n71.0 m \nPolymer 550L \nDichte: 1.04 kg/l \nViskosität: 42/32 sec. \nPolymer-Spülung \n77.5 m \n80.0 m \n84.75 m \n86.0 m \n87.5 m \n99.0 m \n \nLiner für Kernproben \nVon \nBis \nDurchmesser \nSpezifikation \n0.0 m \n88.0 m \nOD 110 mm / ID 104 mm \nPVC dunkelorange \n \nVerfüllung \nVon \nBis \nArt der Verfüllung \nMenge \n \n99.0 m \n7.0 m \nsulfatbeständiger Zement \n(1.8 kg/l) \n5'500 kg \n \n7.0 m \n1.0 m \nKies \n900kg \n \n1.0 m \n0.5 m \nCompactonic \n50kg \n \n0.5 m \n0.0 m \nHumus \n50 kg \n \nNAB 20-01  -  Appendix I\n", 3: ' \nGeophysikalische Bohrlochmessungen \nLogging-Firma: \n \n \n \nterratec Geophysical Services GmbH & CO KG \nMesspersonal: \nMarcos Gracia \n \nDatum \nMessintervall \nMessverfahren \n \nVon \nBis \n \n08.04.2019 \n99.25 m \n 87.50 m \nBHTV (High resolution acoustic  ...
# Document: App-B1_Simple Geological Profile.pdf:
#  {1: 'Legend\nOrganic matter\nRusty, oxidized\nCementation (locally e.g. clast surfaces)\nStriated clasts\nContorted bedding\nCrude stratification\nGravel, cobble, boulder\nclasts (individual outsized\nclasts to diamictic sediments)\nThin bedded\nErosional suface\nBedrock\nox\nDiamictic interbeds\nCarbonate concretion/nodule\nlaminated\nPlant root tubes, rootlets\nBioturbation\nDropstone\n?\n?\n?\nox\n324.8 m a.s.l.\nLower Freshwater \nMolasse (USM)\nFluvial/deltaic\ngravel & sand\nLacustrine sand & fines \n(coarsening upward trend)\nGlacilacustrine to\nlacustrine fines\nGlacilacustrine sediments\n(base possibly glacideltaic,\nfining upward trend)\nGlacigenic\ndiamicts / tills\n412.8 m a.s.l.\nGlacilacustrine fines (w. dropstones)\nCl & Si\nSa\nGr\nScale 1:500\nQTRU\nDepth (m)\n1.6\n6.9\n8.7\n8.2\n13.0\n0.0\n18.2\n23.4\n30.8\n34.0\n80.5\n75.8\n73.5\n71.1\n70.0\n66.0\n61.0\n51.6\n49.0\n45.9\n54.0\n54.8\n85.0\n87.0\n88.0\n98.4\n96.5\n93.0\n91.5\n99.0\n?\nAPPENDIX B1\nNAB 20-01\nQBO Trüllikon-Rudolfingen simplified geological profile\nQTRU Data Report\nDAT.: July 2020\n'}

# %%
## save to json file
import json
output_path = "data/text_files/text_files.json"

with open(output_path, "w", encoding = "utf-8") as file:
    json.dump(document_text, file)
